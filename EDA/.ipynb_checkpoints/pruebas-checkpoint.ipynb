# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/02-Secretaria/PASAJEROS_TRANSPORTES ARANJUEZ SANTA CRUZ.csv", encoding="latin-1", sep=";")
df2 = pd.read_csv("data/02-Secretaria/RECORRIDOS_TRANSPORTES ARANJUEZ SANTA CRUZ.csv", encoding="latin-1", sep=";")

# %%
df1.merge(df2, how="inner", on="NOMBREARCHIVO")

# %%
import re
import json
from pathlib import Path

def extraer_red_peatonal(html_path: Path) -> list:
    with open(html_path, "r", encoding="utf-8") as f:
        contenido = f.read()

    # Regex breakdown:
    # 1. Finds L.polyline( ... )
    # 2. Captures the content inside the first bracket: the list of coordinates [[...]]
    # 3. Ensures it contains the specific "Red Peatonal" color: #000000
    patron_completo = r"L\.polyline\(\s*(\[\[.*?\]\]).*?\"color\":\s*\"#000000\""
    
    # We use re.DOTALL so the dot matches newlines if the JS is formatted across lines
    coincidencias = re.findall(patron_completo, contenido, re.DOTALL)
    
    red_peatonal = []
    
    for coord_string in coincidencias:
        try:
            # Convert the string format [[lat, lon], ...] directly into a Python list
            coords = json.loads(coord_string)
            red_peatonal.append({
                "coords": coords,
                "color": "#000000",
                "tipo": "Red Peatonal"
            })
        except json.JSONDecodeError:
            continue
            
    return red_peatonal

# %%
def extraer_infraestructura(html_path: Path, color_hex: str) -> list:
    with open(html_path, "r", encoding="utf-8") as f:
        contenido = f.read()
    
    # Dynamically look for the specific hex color
    patron = rf"L\.polyline\(\s*(\[\[.*?\]\]).*?\"color\":\s*\"{color_hex}\""
    coincidencias = re.findall(patron, contenido, re.DOTALL)
    
    segmentos = []
    for coord_string in coincidencias:
        try:
            coords = json.loads(coord_string)
            segmentos.append(coords)
        except:
            continue
    return segmentos

ciclorrutas = extraer_infraestructura("mapas/ruta_041_paraderos_aranjuez_suaves_peatonal_ciclorrutas_unificado.html", "#9370DB")
peatonal = extraer_infraestructura("mapas/ruta_041_paraderos_aranjuez_suaves_peatonal_ciclorrutas_unificado.html", "#000000")

# %%
with open("data/ciclorutas_coords.json","w")as f:
    json.dump({"coords":ciclorrutas},f,indent=2)

# %%
with open("data/red_peatonal_coords.json","w")as f:
    json.dump({"coords":peatonal},f,indent=2)

# %%
data = extraer_red_peatonal("ruta_041_paraderos_aranjuez_suaves_peatonal_ciclorrutas_unificado.html")

# %%
import pandas as pd
import numpy as np
import json
import folium

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# C:\Users\ASUS

# %%
import os
pr='C:/Users/ASUS/OneDrive/Documentos/Uni/Monitoría/Inv/ruta n/EDA'
os.chdir(pr)

# %%
df = pd.read_csv("data/rich_041.csv")
with open("data/rutas.json","r") as f:
    rutas = json.load(f)
ruta = rutas["041"]

# %%
m = folium.Map(location=ruta[0], zoom_start=13)

for coord in ruta:
    folium.Marker(
        location = coord,
        icon=folium.Icon(color="red", icon="info-sign"),
        tooltip="041 D"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0a6fe8f9f5730d1018a5d5c583eb75a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0a6fe8f9f5730d1018a5d5c583eb75a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0a6fe8f9f5730d1018a5d5c583eb75a = L.map(
#                 &quot;map_f0a6fe8f9f5730d1018a5d5c583eb75a&quot;,
#                 {
#                     center: [6.287152, -75.552682],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_291e00ab8d275e1cb92a28082f90c594 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_291e00ab8d275e1cb92a28082f90c594.addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var marker_c6259a615c7efda330cd2ebf9290af6d = L.marker(
#                 [6.287152, -75.552682],
#                 {
# }
#             ).addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var icon_bcdf6222b981de72b9f7ea5effb2a079 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_c6259a615c7efda330cd2ebf9290af6d.bindTooltip(
#                 `&lt;div&gt;
#                      041 D
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c6259a615c7efda330cd2ebf9290af6d.setIcon(icon_bcdf6222b981de72b9f7ea5effb2a079);
#
#
#             var marker_fabd5b00f7ca188326b72946467251bf = L.marker(
#                 [6.287194, -75.552676],
#                 {
# }
#             ).addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var icon_f4871fdf1253e37be6d9d96a0a0dfe7e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_fabd5b00f7ca188326b72946467251bf.bindTooltip(
#                 `&lt;div&gt;
#                      041 D
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_fabd5b00f7ca188326b72946467251bf.setIcon(icon_f4871fdf1253e37be6d9d96a0a0dfe7e);
#
#
#             var marker_67a4e5703f479a16102d52b5f24b8ae6 = L.marker(
#                 [6.287234, -75.552665],
#                 {
# }
#             ).addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var icon_4aaa7a7f8e17f774e7b7374ed0ed4d0e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_67a4e5703f479a16102d52b5f24b8ae6.bindTooltip(
#                 `&lt;div&gt;
#                      041 D
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_67a4e5703f479a16102d52b5f24b8ae6.setIcon(icon_4aaa7a7f8e17f774e7b7374ed0ed4d0e);
#
#
#             var marker_4c655aaf6487f255082f1ed69dec8166 = L.marker(
#                 [6.287265, -75.552648],
#                 {
# }
#             ).addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var icon_3d04f49a899dc14daebcb5320ddf7282 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_4c655aaf6487f255082f1ed69dec8166.bindTooltip(
#                 `&lt;div&gt;
#                      041 D
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4c655aaf6487f255082f1ed69dec8166.setIcon(icon_3d04f49a899dc14daebcb5320ddf7282);
#
#
#             var marker_e51c64ccf5fbe958e58ef7eee67816c9 = L.marker(
#                 [6.287302, -75.552619],
#                 {
# }
#             ).addTo(map_f0a6fe8f9f5730d1018a5d5c583eb75a);
#
#
#             var icon_a1e7f40461192f95
